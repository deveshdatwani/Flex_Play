# %%
import kivy
from kivy.app import App
from kivy.uix.label import Label
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
kivy.require('1.01.1')
from kivy.uix.button import Button

class ConnectPage(GridLayout):
	def __init__(self, **kwargs):
		super().__init__(**kwargs)
		self.cols = 2
		self.rows = 4

		self.add_widget(Label(text='username:'))
		self.username = TextInput(multiline=False)
		self.add_widget(self.username)
		
		self.add_widget(Label(text='password:'))
		self.password = TextInput(multiline=False)
		self.add_widget(self.password)

		self.register = Button(text='register new user')
		self.register.bind(on_press=self.register)
		self.add_widget(self.register)

		self.signin = Button(text='sign in')
		self.add_widget(self.signin)

	def register(self, instance):
		username = self.username.text
		password = self.password.text
		print('Creating New Profile')

class Flex_Play(App):
	def build(self):
		return ConnectPage()

if __name__ == '__main__':
	Flex_Play().run()
# Out:
# [INFO   ] [Logger      ] Record log in /home/devesh/.kivy/logs/kivy_20-07-31_30.txt
# [INFO   ] [Kivy        ] v1.10.1
# [INFO   ] [Python      ] v3.8.2 (default, Jul 16 2020, 14:00:26)
# [GCC 9.3.0]
# [INFO   ] [Factory     ] 194 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2(['window_egl_rpi'] ignored)
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] Backend used <gl>
# [INFO   ] [GL          ] OpenGL version <b'4.6 (Compatibility Profile) Mesa 20.0.8'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel'>
# [INFO   ] [GL          ] OpenGL renderer <b'Mesa Intel(R) UHD Graphics 620 (KBL GT2)'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Clipboard   ] Provider: xsel(['clipboard_xclip'] ignored)
# [INFO   ] [CutBuffer   ] cut buffer support enabled
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-fe8a44dc29a9> in <module>
#      38
#      39 if __name__ == '__main__':
# ---> 40         Flex_Play().run()
#
# /usr/lib/python3/dist-packages/kivy/app.py in run(self)
#     798             self.load_config()
#     799             self.load_kv(filename=self.kv_file)
# --> 800             root = self.build()
#     801             if root:
#     802                 self.root = root
#
# <ipython-input-1-fe8a44dc29a9> in build(self)
#      35 class Flex_Play(App):
#      36         def build(self):
# ---> 37                 return ConnectPage()
#      38
#      39 if __name__ == '__main__':
#
# <ipython-input-1-fe8a44dc29a9> in __init__(self, **kwargs)
#      22
#      23                 self.register = Button(text='register new user')
# ---> 24                 self.register.bind(on_press=self.register)
#      25                 self.add_widget(self.register)
#      26
#
# kivy/_event.pyx in kivy._event.EventDispatcher.bind()
#
# AssertionError: <kivy.uix.button.Button object at 0x7f69b4283100> is not callable
